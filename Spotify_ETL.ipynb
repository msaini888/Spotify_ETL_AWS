# %%
import spotipy
import pandas as pd
from spotipy.oauth2 import SpotifyClientCredentials

# %%
client_credentials_manager = SpotifyClientCredentials(client_id='23cf5eb2ede3425e978662c64fa3440e' , client_secret = 'abf818b59de642c6b7b303f337ebb2b0')
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
playlist_link = "https://open.spotify.com/playlist/37i9dQZEVXbNG2KDcFcKOF"

playlist_uri = playlist_link.split("/")[-1].split('?')[-1]

data = sp.playlist_tracks(playlist_uri)

# %%
data['items'][0]['track']['album']['name']
# Out:
# 'i like the way you kiss me'

# %%
data['items'][0]['track']['album']['release_date']
# Out:
# '2024-03-19'

# %%
data['items'][0]['track']['album']['total_tracks']
# Out:
# 1

# %%
album_list = []
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']
    
    album_element = {'album_id':album_id, 'album_name':album_name,'album_release_date':album_release_date,
                     'album_total_tracks':album_total_tracks,'album_url':album_url}
    print(album_element)
    album_list.append(album_element)
# Out:
# {'album_id': '5HIWDdg3g9CTOtnevKDl1z', 'album_name': 'i like the way you kiss me', 'album_release_date': '2024-03-19', 'album_total_tracks': 1, 'album_url': 'https://open.spotify.com/album/5HIWDdg3g9CTOtnevKDl1z'}
# {'album_id': '1vL2mgGTukkrUxXt0loeTN', 'album_name': 'Unreal Unearth: Unheard', 'album_release_date': '2024-03-22', 'album_total_tracks': 20, 'album_url': 'https://open.spotify.com/album/1vL2mgGTukkrUxXt0loeTN'}
# {'album_id': '5tSQtQGkrCJx3hoQxmLgfM', 'album_name': 'Gata Only', 'album_release_date': '2024-02-02', 'album_total_tracks': 1, 'album_url': 'https://open.spotify.com/album/5tSQtQGkrCJx3hoQxmLgfM'}
# {'album_id': '4JDXBZdRPId4devseaAOKH', 'album_name': 'DECIDE', 'album_release_date': '2022-09-16', 'album_total_tracks': 13, 'album_url': 'https://open.spotify.com/album/4JDXBZdRPId4devseaAOKH'}
# ...

# %%
album_list
# Out:
# [{'album_id': '5HIWDdg3g9CTOtnevKDl1z',
#   'album_name': 'i like the way you kiss me',
#   'album_release_date': '2024-03-19',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/5HIWDdg3g9CTOtnevKDl1z'},
#  {'album_id': '1vL2mgGTukkrUxXt0loeTN',
#   'album_name': 'Unreal Unearth: Unheard',
#   'album_release_date': '2024-03-22',
#   'album_total_tracks': 20,
#   'album_url': 'https://open.spotify.com/album/1vL2mgGTukkrUxXt0loeTN'},
#  {'album_id': '5tSQtQGkrCJx3hoQxmLgfM',
#   'album_name': 'Gata Only',
#   'album_release_date': '2024-02-02',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/5tSQtQGkrCJx3hoQxmLgfM'},
#  {'album_id': '4JDXBZdRPId4devseaAOKH',
#   'album_name': 'DECIDE',
#   'album_release_date': '2022-09-16',
#   'album_total_tracks': 13,
#   'album_url': 'https://open.spotify.com/album/4JDXBZdRPId4devseaAOKH'},
#  {'album_id': '168CdR21lfn0TTyw1Pkdcm',
#   'album_name': 'Fireworks & Rollerblades',
# ...

# %%
artist_list = []
for row in data['items']:
    for key,value in row.items():
        if key== 'track':
            for artist in value['artists']:
                artist_dic = {'artist_id':artist['id'],'artist_name':artist['name'],'external_url':artist['href']}
                artist_list.append(artist_dic)

# %%
data['items']
# Out:
# [{'added_at': '2024-04-19T10:25:52Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': 'https://p.scdn.co/mp3-preview/6ce9233edb212fe7cf02273f4369d2c60c28e887?cid=23cf5eb2ede3425e978662c64fa3440e',
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
# ...

# %%
song_list = []
for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    popularity = row['track']['popularity']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_ids = []
    for artist in row['track']['album']['artists']:
        artist_ids.append(artist['id'])
    song_element = {'song_id':song_id,'song_name':song_name,'duration':duration,'song_url':song_url,'popularity':popularity,
                     'song_added':song_added,'album_id':album_id,'artist_ids':artist_ids}
    song_list.append(song_element)

# %%
album_df = pd.DataFrame.from_dict(album_list)

# %%
album_df.head(5)
# Out:
#                  album_id                  album_name album_release_date  \
# 0  5HIWDdg3g9CTOtnevKDl1z  i like the way you kiss me         2024-03-19
# 1  1vL2mgGTukkrUxXt0loeTN     Unreal Unearth: Unheard         2024-03-22
# 2  5tSQtQGkrCJx3hoQxmLgfM                   Gata Only         2024-02-02
# 3  4JDXBZdRPId4devseaAOKH                      DECIDE         2022-09-16
# 4  168CdR21lfn0TTyw1Pkdcm    Fireworks & Rollerblades         2024-04-05
#
#    album_total_tracks                                          album_url
# 0                   1  https://open.spotify.com/album/5HIWDdg3g9CTOtn...
# 1                  20  https://open.spotify.com/album/1vL2mgGTukkrUxX...
# 2                   1  https://open.spotify.com/album/5tSQtQGkrCJx3ho...
# 3                  13  https://open.spotify.com/album/4JDXBZdRPId4dev...
# 4                  15  https://open.spotify.com/album/168CdR21lfn0TTy...

# %%
album_df.shape
# Out:
# (47, 5)

# %%
album_df['album_release_date'] = pd.to_datetime(album_df['album_release_date'])
# Out:
# C:\Users\mohit\AppData\Local\Temp\ipykernel_24624\2236237792.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   album_df['album_release_date'] = pd.to_datetime(album_df['album_release_date'])

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 47 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   album_id            47 non-null     object
#  1   album_name          47 non-null     object
#  2   album_release_date  47 non-null     datetime64[ns]
#  3   album_total_tracks  47 non-null     int64
#  4   album_url           47 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 2.2+ KB

# %%
artist_df = artist_df.drop_duplicates(subset='artist_id')

# %%
artist_df = pd.DataFrame.from_dict(artist_list)

# %%
artist_df.head(5)
# Out:
#                 artist_id artist_name  \
# 0  0PCCGZ0wGLizHt2KZ7hhA2     Artemas
# 1  2FXC3k01G6Gw61bmprjgqS      Hozier
# 2  7CvTknweLr9feJtRGrpDBy  FloyyMenor
# 3  1Yj5Xey7kTwvZla8sqdsdE     Cris Mj
# 4  5p9HO3XC5P3BLxJs5Mtrhm         Djo
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/0PCCGZ0wGLi...
# 1  https://api.spotify.com/v1/artists/2FXC3k01G6G...
# 2  https://api.spotify.com/v1/artists/7CvTknweLr9...
# 3  https://api.spotify.com/v1/artists/1Yj5Xey7kTw...
# 4  https://api.spotify.com/v1/artists/5p9HO3XC5P3...

# %%
artist_df.shape
# Out:
# (58, 3)

# %%
song_df = pd.DataFrame.from_dict(song_list)

# %%
song_df.head(5)
# Out:
#                   song_id                   song_name  duration  \
# 0  2GxrNKugF82CnoRFbQfzPf  i like the way you kiss me    142514
# 1  0AjmK0Eai4zGrLaJwPvrDp                   Too Sweet    251424
# 2  6XjDF6nds4DE2BBbagZol6                   Gata Only    222000
# 3  3qhlB30KknSejmIvZZLjOD            End of Beginning    159245
# 4  3xkHsmpQCBMytMJNiDf3Ii            Beautiful Things    180304
#
#                                             song_url  popularity  \
# 0  https://open.spotify.com/track/2GxrNKugF82CnoR...          99
# 1  https://open.spotify.com/track/0AjmK0Eai4zGrLa...          88
# 2  https://open.spotify.com/track/6XjDF6nds4DE2BB...          98
# 3  https://open.spotify.com/track/3qhlB30KknSejmI...         100
# 4  https://open.spotify.com/track/3xkHsmpQCBMytMJ...          87
#
#              song_added                album_id  \
# 0  2024-04-19T10:25:52Z  5HIWDdg3g9CTOtnevKDl1z
# 1  2024-04-19T10:25:52Z  1vL2mgGTukkrUxXt0loeTN
# ...
